# %%
import torch
import torchvision.transforms as tvt
from torch.utils.data import DataLoader
from tqdm import tqdm
import shutil
import pandas as pd
import numpy as np
import os
torch.manual_seed(1234)
from evaluate_metrics import compute_eer
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score, recall_score, precision_score
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 14}

def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum()

# %%
# load in the wild protocol
supcon_feb07_proto = pd.read_csv("../traindata/supcon_cnsl_feb07/protocol.txt", sep=" ", header=None)
supcon_feb07_proto.columns = ['utt', 'subset', '-', 'label']
supcon_feb07_proto['label'].value_counts()
supcon_feb07_proto['utt'] = supcon_feb07_proto['utt'].apply(lambda x: x.split("/")[-1].split(".")[0])
supcon_feb07_proto
# Out:
#                                    utt subset  -     label
# 0                         LA_T_3424442  train  -  bonafide
# 1                 hifigan_LA_T_3424442  train  -     spoof
# 2                waveglow_LA_T_3424442  train  -     spoof
# 3        hn-sinc-nsf-hifi_LA_T_3424442  train  -     spoof
# 4                         LA_T_3976536  train  -  bonafide
# ...                                ...    ... ..       ...
# 73355                03MAPK0028_000058    dev  -     spoof
# 73356                     LA_T_9861717    dev  -     spoof
# 73357  000036_tortoise-tts_train_grace    dev  -     spoof
# 73358                     LA_T_4019514    dev  -     spoof
# 73359       000166_tortoise-tts_myself  train  -     spoof
#
# [73360 rows x 4 columns]

# %%
supcon_feb07_df = pd.read_csv("../traindata/supcon_cnsl_feb07/df_meta_feb07.csv")
supcon_feb07_df.fillna("-", inplace=True)
supcon_feb07_df = supcon_feb07_df.astype(str)
supcon_feb07_df['Source link'] = supcon_feb07_df['Source link'].apply(lambda x: x.replace("youtu.be", "youtube.com").replace("www.youtube.com", "youtube.com"))
supcon_feb07_df
# Out:
#                Utterence name (file name)   Speaker name TTS or VC  \
# 0                                ziroud_6   TTS_Hooligun       TTS
# 1                        elle_hanni_3.wav          HANNI         -
# 2                   230914_Yonhap_Messi_8     Go HyunSil         -
# 3                             Frontyard_6      TTS_issue       TTS
# 4                            gridanews_10  TTS_gridanews       TTS
# ...                                   ...            ...       ...
# 112349  VC_FanBingBing_to_Tsai_Chin_1.wav      Tsai Chin         -
# 112350  VC_FanBingBing_to_Tsai_Chin_2.wav      Tsai Chin         -
# 112351  VC_FanBingBing_to_Tsai_Chin_3.wav      Tsai Chin         -
# 112352  VC_FanBingBing_to_Tsai_Chin_4.wav      Tsai Chin         -
# 112353  VC_FanBingBing_to_Tsai_Chin_5.wav      Tsai Chin         -
#
#        Is multi-speaker? Language  Gender       Age Noise type 1  \
# 0                     No   Korean    Male     Child        Music
# 1                     No   Korean  Female     Adult        Music
# 2                     No   Korean  Female     Adult        Music
# 3                     No   Korean  Female  Teenager        Music
# 4                     No   Korean    Male     Adult        Music
# ...                  ...      ...     ...       ...          ...
# 112349                 -  Chinese  Female     Elder            -
# 112350                 -  Chinese  Female     Elder            -
# 112351                 -  Chinese  Female     Elder            -
# 112352                 -  Chinese  Female     Elder            -
# 112353                 -  Chinese  Female     Elder            -
#
#                                               Source link  \
# 0       https://youtube.com/672_mR42M2I?si=ZhYgv0GWEc3...
# 1                 https://youtube.com/watch?v=KoTbLLK9-UM
# 2       https://youtube.com/YOgGBg9yD8M?si=W3xTPwXN7zI...
# 3                 https://youtube.com/watch?v=eXcekCx7Bxo
# 4                 https://youtube.com/watch?v=J0RlmWPSlgY
# ...                                                   ...
# 112349  https://huggingface.co/spaces/amphion/singing_...
# 112350  https://huggingface.co/spaces/amphion/singing_...
# 112351  https://huggingface.co/spaces/amphion/singing_...
# 112352  https://huggingface.co/spaces/amphion/singing_...
# 112353  https://huggingface.co/spaces/amphion/singing_...
#
#                                   utt  \
# 0                            ziroud_6
# 1                        elle_hanni_3
# 2               230914_Yonhap_Messi_8
# 3                         Frontyard_6
# 4                        gridanews_10
# ...                               ...
# 112349  VC_FanBingBing_to_Tsai_Chin_1
# 112350  VC_FanBingBing_to_Tsai_Chin_2
# 112351  VC_FanBingBing_to_Tsai_Chin_3
# 112352  VC_FanBingBing_to_Tsai_Chin_4
# 112353  VC_FanBingBing_to_Tsai_Chin_5
#
#                                                      path     label  \
# 0                                       fake/ziroud_6.wav     spoof
# 1                                   real/elle_hanni_3.wav  bonafide
# 2                          real/230914_Yonhap_Messi_8.wav  bonafide
# 3                                    fake/Frontyard_6.wav     spoof
# 4                                   fake/gridanews_10.wav     spoof
# ...                                                   ...       ...
# 112349  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 112350  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 112351  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 112352  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 112353  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
#
#               group      Model
# 0       internOct24          -
# 1       internOct24          -
# 2       internOct24          -
# 3       internOct24          -
# 4       internOct24          -
# ...             ...        ...
# 112349   intern_jan  Diffusion
# 112350   intern_jan  Diffusion
# 112351   intern_jan  Diffusion
# 112352   intern_jan  Diffusion
# 112353   intern_jan  Diffusion
#
# [112354 rows x 14 columns]

# %%
supcon_feb07_df[supcon_feb07_df['group']=='intern_jan']
# Out:
#                Utterence name (file name)    Speaker name TTS or VC  \
# 111542                 Olivia_Vella_1.wav    Olivia Vella         -
# 111543                Lucy_Androski_3.wav   Lucy Androski         -
# 111544                     Gye-Josu_4.wav        Gye-Josu         -
# 111545                         yoon_2.wav  President Yoon         -
# 111546                 Kang_JiYoung_3.wav    Kang JiYoung         -
# ...                                   ...             ...       ...
# 112349  VC_FanBingBing_to_Tsai_Chin_1.wav       Tsai Chin         -
# 112350  VC_FanBingBing_to_Tsai_Chin_2.wav       Tsai Chin         -
# 112351  VC_FanBingBing_to_Tsai_Chin_3.wav       Tsai Chin         -
# 112352  VC_FanBingBing_to_Tsai_Chin_4.wav       Tsai Chin         -
# 112353  VC_FanBingBing_to_Tsai_Chin_5.wav       Tsai Chin         -
#
#        Is multi-speaker? Language  Gender       Age Noise type 1  \
# 111542                No  English  Female  Teenager            -
# 111543                No  English  Female  Teenager            -
# 111544                No  Chinese    Male     Elder            -
# 111545                No   Korean    Male     Adult            -
# 111546                No   Korean  Female     Adult            -
# ...                  ...      ...     ...       ...          ...
# 112349                 -  Chinese  Female     Elder            -
# 112350                 -  Chinese  Female     Elder            -
# 112351                 -  Chinese  Female     Elder            -
# 112352                 -  Chinese  Female     Elder            -
# 112353                 -  Chinese  Female     Elder            -
#
#                                               Source link  \
# 111542            https://youtube.com/watch?v=Eu_Gl0woeOw
# 111543            https://youtube.com/watch?v=0vdPxLfAsqo
# 111544            https://youtube.com/watch?v=voEZnAtIpCI
# 111545            https://youtube.com/watch?v=7pss74wlg8E
# 111546            https://youtube.com/watch?v=nrH4sJ4iCuY
# ...                                                   ...
# 112349  https://huggingface.co/spaces/amphion/singing_...
# 112350  https://huggingface.co/spaces/amphion/singing_...
# 112351  https://huggingface.co/spaces/amphion/singing_...
# 112352  https://huggingface.co/spaces/amphion/singing_...
# 112353  https://huggingface.co/spaces/amphion/singing_...
#
#                                   utt  \
# 111542                 Olivia_Vella_1
# 111543                Lucy_Androski_3
# 111544                     Gye-Josu_4
# 111545                         yoon_2
# 111546                 Kang_JiYoung_3
# ...                               ...
# 112349  VC_FanBingBing_to_Tsai_Chin_1
# 112350  VC_FanBingBing_to_Tsai_Chin_2
# 112351  VC_FanBingBing_to_Tsai_Chin_3
# 112352  VC_FanBingBing_to_Tsai_Chin_4
# 112353  VC_FanBingBing_to_Tsai_Chin_5
#
#                                                      path     label  \
# 111542               ./2024_RealSample/Olivia_Vella_1.wav  bonafide
# 111543              ./2024_RealSample/Lucy_Androski_3.wav  bonafide
# 111544                   ./2024_RealSample/Gye-Josu_4.wav  bonafide
# 111545                       ./2024_RealSample/yoon_2.wav  bonafide
# 111546               ./2024_RealSample/Kang_JiYoung_3.wav  bonafide
# ...                                                   ...       ...
# 112349  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 112350  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 112351  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 112352  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 112353  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
#
#              group      Model
# 111542  intern_jan          -
# 111543  intern_jan          -
# 111544  intern_jan          -
# 111545  intern_jan          -
# 111546  intern_jan          -
# ...            ...        ...
# 112349  intern_jan  Diffusion
# 112350  intern_jan  Diffusion
# 112351  intern_jan  Diffusion
# 112352  intern_jan  Diffusion
# 112353  intern_jan  Diffusion
#
# [812 rows x 14 columns]

# %%
proto_merge = pd.merge(supcon_feb07_df, supcon_feb07_proto, on='utt', how='inner')
proto_merge
# Out:
#               Utterence name (file name)  Speaker name TTS or VC  \
# 0                               ziroud_6  TTS_Hooligun       TTS
# 1                       elle_hanni_3.wav         HANNI         -
# 2                  230914_Yonhap_Messi_8    Go HyunSil         -
# 3                            Frontyard_6     TTS_issue       TTS
# 4                         NDH_Blueclub_6  NDH_Blueclub       TTS
# ...                                  ...           ...       ...
# 45241  VC_FanBingBing_to_Tsai_Chin_1.wav     Tsai Chin         -
# 45242  VC_FanBingBing_to_Tsai_Chin_2.wav     Tsai Chin         -
# 45243  VC_FanBingBing_to_Tsai_Chin_3.wav     Tsai Chin         -
# 45244  VC_FanBingBing_to_Tsai_Chin_4.wav     Tsai Chin         -
# 45245  VC_FanBingBing_to_Tsai_Chin_5.wav     Tsai Chin         -
#
#       Is multi-speaker? Language  Gender       Age Noise type 1  \
# 0                    No   Korean    Male     Child        Music
# 1                    No   Korean  Female     Adult        Music
# 2                    No   Korean  Female     Adult        Music
# 3                    No   Korean  Female  Teenager        Music
# 4                   Yes   Korean    Male     Adult        Music
# ...                 ...      ...     ...       ...          ...
# 45241                 -  Chinese  Female     Elder            -
# 45242                 -  Chinese  Female     Elder            -
# 45243                 -  Chinese  Female     Elder            -
# 45244                 -  Chinese  Female     Elder            -
# 45245                 -  Chinese  Female     Elder            -
#
#                                              Source link  \
# 0      https://youtube.com/672_mR42M2I?si=ZhYgv0GWEc3...
# 1                https://youtube.com/watch?v=KoTbLLK9-UM
# 2      https://youtube.com/YOgGBg9yD8M?si=W3xTPwXN7zI...
# 3                https://youtube.com/watch?v=eXcekCx7Bxo
# 4                https://youtube.com/watch?v=l1mUUp0puys
# ...                                                  ...
# 45241  https://huggingface.co/spaces/amphion/singing_...
# 45242  https://huggingface.co/spaces/amphion/singing_...
# 45243  https://huggingface.co/spaces/amphion/singing_...
# 45244  https://huggingface.co/spaces/amphion/singing_...
# 45245  https://huggingface.co/spaces/amphion/singing_...
#
#                                  utt  \
# 0                           ziroud_6
# 1                       elle_hanni_3
# 2              230914_Yonhap_Messi_8
# 3                        Frontyard_6
# 4                     NDH_Blueclub_6
# ...                              ...
# 45241  VC_FanBingBing_to_Tsai_Chin_1
# 45242  VC_FanBingBing_to_Tsai_Chin_2
# 45243  VC_FanBingBing_to_Tsai_Chin_3
# 45244  VC_FanBingBing_to_Tsai_Chin_4
# 45245  VC_FanBingBing_to_Tsai_Chin_5
#
#                                                     path   label_x  \
# 0                                      fake/ziroud_6.wav     spoof
# 1                                  real/elle_hanni_3.wav  bonafide
# 2                         real/230914_Yonhap_Messi_8.wav  bonafide
# 3                                   fake/Frontyard_6.wav     spoof
# 4                                fake/NDH_Blueclub_6.wav     spoof
# ...                                                  ...       ...
# 45241  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 45242  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 45243  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 45244  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 45245  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
#
#              group      Model subset      -   label_y
# 0      internOct24          -    dev      -     spoof
# 1      internOct24          -   eval  Music  bonafide
# 2      internOct24          -    dev  Music  bonafide
# 3      internOct24          -   eval  Music     spoof
# 4      internOct24          -    dev      -     spoof
# ...            ...        ...    ...    ...       ...
# 45241   intern_jan  Diffusion   eval      -     spoof
# 45242   intern_jan  Diffusion   eval      -     spoof
# 45243   intern_jan  Diffusion  train      -     spoof
# 45244   intern_jan  Diffusion   eval      -     spoof
# 45245   intern_jan  Diffusion   eval      -     spoof
#
# [45246 rows x 17 columns]

# %%
proto_merge[proto_merge['group']=='intern_jan']
# Out:
#               Utterence name (file name)    Speaker name TTS or VC  \
# 44434                 Olivia_Vella_1.wav    Olivia Vella         -
# 44435                Lucy_Androski_3.wav   Lucy Androski         -
# 44436                     Gye-Josu_4.wav        Gye-Josu         -
# 44437                         yoon_2.wav  President Yoon         -
# 44438                 Kang_JiYoung_3.wav    Kang JiYoung         -
# ...                                  ...             ...       ...
# 45241  VC_FanBingBing_to_Tsai_Chin_1.wav       Tsai Chin         -
# 45242  VC_FanBingBing_to_Tsai_Chin_2.wav       Tsai Chin         -
# 45243  VC_FanBingBing_to_Tsai_Chin_3.wav       Tsai Chin         -
# 45244  VC_FanBingBing_to_Tsai_Chin_4.wav       Tsai Chin         -
# 45245  VC_FanBingBing_to_Tsai_Chin_5.wav       Tsai Chin         -
#
#       Is multi-speaker? Language  Gender       Age Noise type 1  \
# 44434                No  English  Female  Teenager            -
# 44435                No  English  Female  Teenager            -
# 44436                No  Chinese    Male     Elder            -
# 44437                No   Korean    Male     Adult            -
# 44438                No   Korean  Female     Adult            -
# ...                 ...      ...     ...       ...          ...
# 45241                 -  Chinese  Female     Elder            -
# 45242                 -  Chinese  Female     Elder            -
# 45243                 -  Chinese  Female     Elder            -
# 45244                 -  Chinese  Female     Elder            -
# 45245                 -  Chinese  Female     Elder            -
#
#                                              Source link  \
# 44434            https://youtube.com/watch?v=Eu_Gl0woeOw
# 44435            https://youtube.com/watch?v=0vdPxLfAsqo
# 44436            https://youtube.com/watch?v=voEZnAtIpCI
# 44437            https://youtube.com/watch?v=7pss74wlg8E
# 44438            https://youtube.com/watch?v=nrH4sJ4iCuY
# ...                                                  ...
# 45241  https://huggingface.co/spaces/amphion/singing_...
# 45242  https://huggingface.co/spaces/amphion/singing_...
# 45243  https://huggingface.co/spaces/amphion/singing_...
# 45244  https://huggingface.co/spaces/amphion/singing_...
# 45245  https://huggingface.co/spaces/amphion/singing_...
#
#                                  utt  \
# 44434                 Olivia_Vella_1
# 44435                Lucy_Androski_3
# 44436                     Gye-Josu_4
# 44437                         yoon_2
# 44438                 Kang_JiYoung_3
# ...                              ...
# 45241  VC_FanBingBing_to_Tsai_Chin_1
# 45242  VC_FanBingBing_to_Tsai_Chin_2
# 45243  VC_FanBingBing_to_Tsai_Chin_3
# 45244  VC_FanBingBing_to_Tsai_Chin_4
# 45245  VC_FanBingBing_to_Tsai_Chin_5
#
#                                                     path   label_x  \
# 44434               ./2024_RealSample/Olivia_Vella_1.wav  bonafide
# 44435              ./2024_RealSample/Lucy_Androski_3.wav  bonafide
# 44436                   ./2024_RealSample/Gye-Josu_4.wav  bonafide
# 44437                       ./2024_RealSample/yoon_2.wav  bonafide
# 44438               ./2024_RealSample/Kang_JiYoung_3.wav  bonafide
# ...                                                  ...       ...
# 45241  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 45242  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 45243  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 45244  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
# 45245  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...     spoof
#
#             group      Model subset  -   label_y
# 44434  intern_jan          -  train  -  bonafide
# 44435  intern_jan          -   eval  -  bonafide
# 44436  intern_jan          -  train  -  bonafide
# 44437  intern_jan          -   eval  -  bonafide
# 44438  intern_jan          -   eval  -  bonafide
# ...           ...        ...    ... ..       ...
# 45241  intern_jan  Diffusion   eval  -     spoof
# 45242  intern_jan  Diffusion   eval  -     spoof
# 45243  intern_jan  Diffusion  train  -     spoof
# 45244  intern_jan  Diffusion   eval  -     spoof
# 45245  intern_jan  Diffusion   eval  -     spoof
#
# [812 rows x 17 columns]

# %%
intern24_df = pd.read_csv("../traindata/intern_2024/metadata_jan30.csv")
intern24_df.fillna("-", inplace=True)
intern24_df = intern24_df.astype(str)
# print(intern24_df.head)
intern24_df['source_group'] = intern24_df.apply(lambda x: x['Source link'].replace("//", "/").split("/")[1], axis=1)
intern24_df['source_group'] = intern24_df['source_group'].apply(lambda x: 'www.youtube.com' if (x == 'youtu.be' or x == 'youtube.com') else x)
intern24_df
# Out:
#                                utt         Utterence name (file name)  \
# 0                   Olivia_Vella_1                 Olivia_Vella_1.wav
# 1                  Lucy_Androski_3                Lucy_Androski_3.wav
# 2                       Gye-Josu_4                     Gye-Josu_4.wav
# 3                           yoon_2                         yoon_2.wav
# 4                   Kang_JiYoung_3                 Kang_JiYoung_3.wav
# ..                             ...                                ...
# 807  VC_FanBingBing_to_Tsai_Chin_1  VC_FanBingBing_to_Tsai_Chin_1.wav
# 808  VC_FanBingBing_to_Tsai_Chin_2  VC_FanBingBing_to_Tsai_Chin_2.wav
# 809  VC_FanBingBing_to_Tsai_Chin_3  VC_FanBingBing_to_Tsai_Chin_3.wav
# 810  VC_FanBingBing_to_Tsai_Chin_4  VC_FanBingBing_to_Tsai_Chin_4.wav
# 811  VC_FanBingBing_to_Tsai_Chin_5  VC_FanBingBing_to_Tsai_Chin_5.wav
#
#        Speaker name Is multi-speaker? Language  Gender Noise type 1       Age  \
# 0      Olivia Vella                No  English  Female            -  Teenager
# 1     Lucy Androski                No  English  Female            -  Teenager
# 2          Gye-Josu                No  Chinese    Male            -     Elder
# 3    President Yoon                No   Korean    Male            -     Adult
# 4      Kang JiYoung                No   Korean  Female            -     Adult
# ..              ...               ...      ...     ...          ...       ...
# 807       Tsai Chin                 -  Chinese  Female            -     Elder
# 808       Tsai Chin                 -  Chinese  Female            -     Elder
# 809       Tsai Chin                 -  Chinese  Female            -     Elder
# 810       Tsai Chin                 -  Chinese  Female            -     Elder
# 811       Tsai Chin                 -  Chinese  Female            -     Elder
#
#                                            Source link     label  \
# 0          https://www.youtube.com/watch?v=Eu_Gl0woeOw  bonafide
# 1          https://www.youtube.com/watch?v=0vdPxLfAsqo  bonafide
# 2          https://www.youtube.com/watch?v=voEZnAtIpCI  bonafide
# 3          https://www.youtube.com/watch?v=7pss74wlg8E  bonafide
# 4          https://www.youtube.com/watch?v=nrH4sJ4iCuY  bonafide
# ..                                                 ...       ...
# 807  https://huggingface.co/spaces/amphion/singing_...     spoof
# 808  https://huggingface.co/spaces/amphion/singing_...     spoof
# 809  https://huggingface.co/spaces/amphion/singing_...     spoof
# 810  https://huggingface.co/spaces/amphion/singing_...     spoof
# 811  https://huggingface.co/spaces/amphion/singing_...     spoof
#
#                                                   path      Model Noise Type  \
# 0                 ./2024_RealSample/Olivia_Vella_1.wav          -          -
# 1                ./2024_RealSample/Lucy_Androski_3.wav          -          -
# 2                     ./2024_RealSample/Gye-Josu_4.wav          -          -
# 3                         ./2024_RealSample/yoon_2.wav          -          -
# 4                 ./2024_RealSample/Kang_JiYoung_3.wav          -          -
# ..                                                 ...        ...        ...
# 807  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
# 808  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
# 809  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
# 810  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
# 811  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
#
#         source_group
# 0    www.youtube.com
# 1    www.youtube.com
# 2    www.youtube.com
# 3    www.youtube.com
# 4    www.youtube.com
# ..               ...
# 807   huggingface.co
# 808   huggingface.co
# 809   huggingface.co
# 810   huggingface.co
# 811   huggingface.co
#
# [812 rows x 14 columns]

# %%
mergedf = pd.merge(supcon_feb07_df, intern24_df, on='utt', how='inner')
mergedf
# Out:
#           Utterence name (file name)_x  Speaker name_x TTS or VC  \
# 0                   Olivia_Vella_1.wav    Olivia Vella         -
# 1                  Lucy_Androski_3.wav   Lucy Androski         -
# 2                       Gye-Josu_4.wav        Gye-Josu         -
# 3                           yoon_2.wav  President Yoon         -
# 4                   Kang_JiYoung_3.wav    Kang JiYoung         -
# ..                                 ...             ...       ...
# 807  VC_FanBingBing_to_Tsai_Chin_1.wav       Tsai Chin         -
# 808  VC_FanBingBing_to_Tsai_Chin_2.wav       Tsai Chin         -
# 809  VC_FanBingBing_to_Tsai_Chin_3.wav       Tsai Chin         -
# 810  VC_FanBingBing_to_Tsai_Chin_4.wav       Tsai Chin         -
# 811  VC_FanBingBing_to_Tsai_Chin_5.wav       Tsai Chin         -
#
#     Is multi-speaker?_x Language_x Gender_x     Age_x Noise type 1_x  \
# 0                    No    English   Female  Teenager              -
# 1                    No    English   Female  Teenager              -
# 2                    No    Chinese     Male     Elder              -
# 3                    No     Korean     Male     Adult              -
# 4                    No     Korean   Female     Adult              -
# ..                  ...        ...      ...       ...            ...
# 807                   -    Chinese   Female     Elder              -
# 808                   -    Chinese   Female     Elder              -
# 809                   -    Chinese   Female     Elder              -
# 810                   -    Chinese   Female     Elder              -
# 811                   -    Chinese   Female     Elder              -
#
#                                          Source link_x  \
# 0              https://youtube.com/watch?v=Eu_Gl0woeOw
# 1              https://youtube.com/watch?v=0vdPxLfAsqo
# 2              https://youtube.com/watch?v=voEZnAtIpCI
# 3              https://youtube.com/watch?v=7pss74wlg8E
# 4              https://youtube.com/watch?v=nrH4sJ4iCuY
# ..                                                 ...
# 807  https://huggingface.co/spaces/amphion/singing_...
# 808  https://huggingface.co/spaces/amphion/singing_...
# 809  https://huggingface.co/spaces/amphion/singing_...
# 810  https://huggingface.co/spaces/amphion/singing_...
# 811  https://huggingface.co/spaces/amphion/singing_...
#
#                                utt  ... Language_y Gender_y Noise type 1_y  \
# 0                   Olivia_Vella_1  ...    English   Female              -
# 1                  Lucy_Androski_3  ...    English   Female              -
# 2                       Gye-Josu_4  ...    Chinese     Male              -
# 3                           yoon_2  ...     Korean     Male              -
# 4                   Kang_JiYoung_3  ...     Korean   Female              -
# ..                             ...  ...        ...      ...            ...
# 807  VC_FanBingBing_to_Tsai_Chin_1  ...    Chinese   Female              -
# 808  VC_FanBingBing_to_Tsai_Chin_2  ...    Chinese   Female              -
# 809  VC_FanBingBing_to_Tsai_Chin_3  ...    Chinese   Female              -
# 810  VC_FanBingBing_to_Tsai_Chin_4  ...    Chinese   Female              -
# 811  VC_FanBingBing_to_Tsai_Chin_5  ...    Chinese   Female              -
#
#         Age_y                                      Source link_y   label_y  \
# 0    Teenager        https://www.youtube.com/watch?v=Eu_Gl0woeOw  bonafide
# 1    Teenager        https://www.youtube.com/watch?v=0vdPxLfAsqo  bonafide
# 2       Elder        https://www.youtube.com/watch?v=voEZnAtIpCI  bonafide
# 3       Adult        https://www.youtube.com/watch?v=7pss74wlg8E  bonafide
# 4       Adult        https://www.youtube.com/watch?v=nrH4sJ4iCuY  bonafide
# ..        ...                                                ...       ...
# 807     Elder  https://huggingface.co/spaces/amphion/singing_...     spoof
# 808     Elder  https://huggingface.co/spaces/amphion/singing_...     spoof
# 809     Elder  https://huggingface.co/spaces/amphion/singing_...     spoof
# 810     Elder  https://huggingface.co/spaces/amphion/singing_...     spoof
# 811     Elder  https://huggingface.co/spaces/amphion/singing_...     spoof
#
#                                                 path_y    Model_y Noise Type  \
# 0                 ./2024_RealSample/Olivia_Vella_1.wav          -          -
# 1                ./2024_RealSample/Lucy_Androski_3.wav          -          -
# 2                     ./2024_RealSample/Gye-Josu_4.wav          -          -
# 3                         ./2024_RealSample/yoon_2.wav          -          -
# 4                 ./2024_RealSample/Kang_JiYoung_3.wav          -          -
# ..                                                 ...        ...        ...
# 807  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
# 808  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
# 809  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
# 810  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
# 811  ./2024_FakeSample/VC_Sample/VC_FanBingBing_to_...  Diffusion          -
#
#         source_group
# 0    www.youtube.com
# 1    www.youtube.com
# 2    www.youtube.com
# 3    www.youtube.com
# 4    www.youtube.com
# ..               ...
# 807   huggingface.co
# 808   huggingface.co
# 809   huggingface.co
# 810   huggingface.co
# 811   huggingface.co
#
# [812 rows x 27 columns]

# %%
print(mergedf['group'].value_counts())
print(mergedf['subset_x'].value_counts())
# Out:
# intern_jan    812
# Name: group, dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'subset_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 print(mergedf['group'].value_counts())
# ----> 2 print(mergedf['subset_x'].value_counts())
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'subset_x'
